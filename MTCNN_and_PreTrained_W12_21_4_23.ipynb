# %% [markdown]
# <a href="https://colab.research.google.com/github/NgoThanhNha/Artificial_Intelligence/blob/main/MTCNN_and_PreTrained_W12_21_4_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 21.7 MB/s eta 0:00:00
# ...

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt
filename = 'Tapthe.JPG'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()

faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
  x,y,width,heigt = face['box']
  rect = plt.Rectangle((x,y),width,heigt,fill = False, color = 'red')
  ax.add_patch(rect)
plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 39ms/step

# %%
filename = 'Tapthe2.jpg'
img = plt.imread(filename)
plt.imshow(img)

faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
  x,y,width,heigt = face['box']
  rect = plt.Rectangle((x,y),width,heigt,fill = False, color = 'red')
  ax.add_patch(rect)
plt.show()
# Out:
# ...
# 5/5 [==============================] - 0s 52ms/step

# %%
filename = 'Tapthe3.jpg'
img = plt.imread(filename)
plt.imshow(img)

faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
  x,y,width,heigt = face['box']
  rect = plt.Rectangle((x,y),width,heigt,fill = False, color = 'red')
  ax.add_patch(rect)
  plt.savefig('/content/sample_data')
plt.show()
# Out:
# ...
# 13/13 [==============================] - 1s 39ms/step

# %%
filename = 'Tapthe.JPG'
img = plt.imread(filename)
plt.imshow(img)

faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
  x,y,width,heigt = face['box']
  rect = plt.Rectangle((x,y),width,heigt,fill = False, color = 'red')
  ax.add_patch(rect)
  for key, value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color = 'green')
    ax.add_patch(dot)
  plt.savefig('/content/Tapthe_save.jpg')
plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 36ms/step

# %%
filename = 'Tapthe_save.jpg'
img = plt.imread(filename)
plt.imshow(img)

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt

def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1, y1, width, height = result_list[i]['box']
    x2, y2 = x1 + width, y1 + height
    plt.subplot(1, len(result_list), i + 1)
    plt.axis('off')
    plt.imshow(data[y1:y2, x1:x2])
  plt.show()

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

img_path = 'Einstein.JPG'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n03476991', 'hair_spray', 0.116714254), ('n04296562', 'stage', 0.10152609), ('n03595614', 'jersey', 0.041691862)]

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np
from tensorflow.keras.preprocessing import image

# Tạo một instance của VGG16
model = VGG16(weights='imagenet')

# Load hình ảnh vào Keras và tiền xử lý nó để chuẩn bị cho mô hình
img_path = 'xetai.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Sử dụng mô hình để phân loại hình ảnh
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 811ms/step
# Predicted: [('n03796401', 'moving_van', 0.6529434), ('n04467665', 'trailer_truck', 0.29013172), ('n03417042', 'garbage_truck', 0.044694815)]
